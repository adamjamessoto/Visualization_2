# %%
import pandas as pd

df = pd.read_json('westbrookShots_15_16.json')

# %%
df.head()
# Out:
#             action_type  defender_distance    defender_name  dribbles  \
# 0   Alley Oop Dunk Shot                4.1     Rubio, Ricky         0
# 1   Alley Oop Dunk Shot                3.8  Faried, Kenneth         0
# 2  Alley Oop Layup shot                0.0                          0
# 3  Alley Oop Layup shot                1.5    Walker, Kemba         0
# 4  Alley Oop Layup shot                5.9  Felton, Raymond         0
#
#    espn_game_id  espn_player_id   game_date  minutes_remaining  \
# 0     400828461            3468  2016-01-12                  1
# 1     400828514            3468  2016-01-19                  1
# 2     400828689            3468  2016-02-11                  0
# 3     400828523            3468  2016-01-20                  4
# 4     400828469            3468  2016-01-13                  6
#
#                 name                opponent ...  seconds_remaining  \
# 0  Russell Westbrook  Minnesota Timberwolves ...                  4
# 1  Russell Westbrook          Denver Nuggets ...                 40
# 2  Russell Westbrook    New Orleans Pelicans ...                 31
# 3  Russell Westbrook       Charlotte Hornets ...                 10
# 4  Russell Westbrook        Dallas Mavericks ...                 33
#
#    shot_clock  shot_distance  shot_made_flag       shot_type     team_id  \
# 0        21.2            1.6               1  2PT Field Goal  1610612760
# 1        12.8            3.3               1  2PT Field Goal  1610612760
# 2         0.0            0.0               1  2PT Field Goal  1610612760
# 3        15.0            1.6               1  2PT Field Goal  1610612760
# 4        20.9            3.2               0  2PT Field Goal  1610612760
#
#                team_name  touch_time   x   y
# 0  Oklahoma City Thunder         0.0   0   1
# 1  Oklahoma City Thunder         0.0   0   1
# 2  Oklahoma City Thunder         0.0  10   7
# 3  Oklahoma City Thunder         1.1  12  11
# 4  Oklahoma City Thunder         0.4  -7   3
#
# [5 rows x 22 columns]

# %%
list(df)
# Out:
# [u'action_type',
#  u'defender_distance',
#  u'defender_name',
#  u'dribbles',
#  u'espn_game_id',
#  u'espn_player_id',
#  u'game_date',
#  u'minutes_remaining',
#  u'name',
#  u'opponent',
#  u'period',
#  u'season',
#  u'seconds_remaining',
#  u'shot_clock',
#  u'shot_distance',
#  u'shot_made_flag',
#  u'shot_type',
#  u'team_id',
#  u'team_name',
#  u'touch_time',
#  u'x',
#  u'y']

# %%
df[['name','opponent', 'shot_made_flag', 'shot_type', 'period']]
# Out:
#                    name                opponent  shot_made_flag  \
# 0     Russell Westbrook  Minnesota Timberwolves               1
# 1     Russell Westbrook          Denver Nuggets               1
# 2     Russell Westbrook    New Orleans Pelicans               1
# 3     Russell Westbrook       Charlotte Hornets               1
# 4     Russell Westbrook        Dallas Mavericks               0
# 5     Russell Westbrook     Cleveland Cavaliers               1
# 6     Russell Westbrook  Minnesota Timberwolves               1
# 7     Russell Westbrook        Sacramento Kings               1
# 8     Russell Westbrook  Minnesota Timberwolves               1
# 9     Russell Westbrook        Sacramento Kings               1
# 10    Russell Westbrook              Miami Heat               1
# 11    Russell Westbrook       Charlotte Hornets               1
# 12    Russell Westbrook           Orlando Magic               1
# 13    Russell Westbrook  Minnesota Timberwolves               1
# 14    Russell Westbrook      Los Angeles Lakers               1
# 15    Russell Westbrook          Denver Nuggets               0
# 16    Russell Westbrook        Dallas Mavericks               1
# 17    Russell Westbrook               Utah Jazz               1
# 18    Russell Westbrook    Los Angeles Clippers               1
# 19    Russell Westbrook          Denver Nuggets               1
# 20    Russell Westbrook      Los Angeles Lakers               1
# 21    Russell Westbrook          Boston Celtics               1
# 22    Russell Westbrook          Denver Nuggets               1
# 23    Russell Westbrook       San Antonio Spurs               1
# 24    Russell Westbrook      Philadelphia 76ers               1
# 25    Russell Westbrook         New York Knicks               1
# 26    Russell Westbrook          Boston Celtics               1
# 27    Russell Westbrook      Philadelphia 76ers               1
# 28    Russell Westbrook           Brooklyn Nets               1
# 29    Russell Westbrook         Houston Rockets               1
# ...                 ...                     ...             ...
# 1377  Russell Westbrook  Portland Trail Blazers               0
# 1378  Russell Westbrook           Brooklyn Nets               0
# 1379  Russell Westbrook           Chicago Bulls               1
# 1380  Russell Westbrook           Orlando Magic               0
# 1381  Russell Westbrook   Golden State Warriors               1
# 1382  Russell Westbrook        Dallas Mavericks               1
# 1383  Russell Westbrook      Washington Wizards               1
# 1384  Russell Westbrook   Golden State Warriors               0
# 1385  Russell Westbrook    New Orleans Pelicans               0
# 1386  Russell Westbrook          Denver Nuggets               1
# 1387  Russell Westbrook       Memphis Grizzlies               0
# 1388  Russell Westbrook    New Orleans Pelicans               1
# 1389  Russell Westbrook      Washington Wizards               0
# 1390  Russell Westbrook         Milwaukee Bucks               0
# 1391  Russell Westbrook            Phoenix Suns               1
# 1392  Russell Westbrook       San Antonio Spurs               0
# 1393  Russell Westbrook      Philadelphia 76ers               0
# 1394  Russell Westbrook            Phoenix Suns               1
# 1395  Russell Westbrook    New Orleans Pelicans               0
# 1396  Russell Westbrook  Portland Trail Blazers               0
# 1397  Russell Westbrook      Washington Wizards               1
# 1398  Russell Westbrook            Phoenix Suns               1
# 1399  Russell Westbrook        Dallas Mavericks               0
# 1400  Russell Westbrook              Miami Heat               0
# 1401  Russell Westbrook              Miami Heat               0
# 1402  Russell Westbrook              Miami Heat               0
# 1403  Russell Westbrook       Charlotte Hornets               1
# 1404  Russell Westbrook              Miami Heat               1
# 1405  Russell Westbrook       San Antonio Spurs               1
# 1406  Russell Westbrook          Boston Celtics               0
#
#            shot_type  period
# 0     2PT Field Goal       2
# 1     2PT Field Goal       4
# 2     2PT Field Goal       2
# 3     2PT Field Goal       3
# 4     2PT Field Goal       1
# 5     2PT Field Goal       1
# 6     2PT Field Goal       3
# 7     2PT Field Goal       1
# 8     2PT Field Goal       3
# 9     2PT Field Goal       3
# 10    2PT Field Goal       2
# 11    2PT Field Goal       3
# 12    2PT Field Goal       1
# 13    2PT Field Goal       3
# 14    2PT Field Goal       1
# 15    2PT Field Goal       3
# 16    2PT Field Goal       1
# 17    2PT Field Goal       3
# 18    2PT Field Goal       1
# 19    2PT Field Goal       2
# 20    2PT Field Goal       1
# 21    2PT Field Goal       1
# 22    2PT Field Goal       4
# 23    2PT Field Goal       3
# 24    2PT Field Goal       1
# 25    2PT Field Goal       1
# 26    2PT Field Goal       1
# 27    2PT Field Goal       3
# 28    2PT Field Goal       2
# 29    2PT Field Goal       4
# ...              ...     ...
# 1377  2PT Field Goal       1
# 1378  2PT Field Goal       2
# 1379  2PT Field Goal       1
# 1380  2PT Field Goal       1
# 1381  2PT Field Goal       2
# 1382  2PT Field Goal       2
# 1383  2PT Field Goal       1
# 1384  2PT Field Goal       4
# 1385  2PT Field Goal       4
# 1386  2PT Field Goal       3
# 1387  2PT Field Goal       3
# 1388  2PT Field Goal       1
# 1389  2PT Field Goal       4
# 1390  2PT Field Goal       1
# 1391  2PT Field Goal       1
# 1392  2PT Field Goal       1
# 1393  2PT Field Goal       2
# 1394  2PT Field Goal       1
# 1395  2PT Field Goal       1
# 1396  2PT Field Goal       1
# 1397  2PT Field Goal       1
# 1398  2PT Field Goal       2
# 1399  2PT Field Goal       1
# 1400  2PT Field Goal       3
# 1401  2PT Field Goal       1
# 1402  2PT Field Goal       1
# 1403  2PT Field Goal       3
# 1404  2PT Field Goal       1
# 1405  2PT Field Goal       1
# 1406  2PT Field Goal       4
#
# [1407 rows x 5 columns]

# %%
data = df[['name','opponent', 'period', 'shot_type', 'shot_made_flag']]
data.head()
# Out:
#                 name                opponent  period       shot_type  \
# 0  Russell Westbrook  Minnesota Timberwolves       2  2PT Field Goal
# 1  Russell Westbrook          Denver Nuggets       4  2PT Field Goal
# 2  Russell Westbrook    New Orleans Pelicans       2  2PT Field Goal
# 3  Russell Westbrook       Charlotte Hornets       3  2PT Field Goal
# 4  Russell Westbrook        Dallas Mavericks       1  2PT Field Goal
#
#    shot_made_flag
# 0               1
# 1               1
# 2               1
# 3               1
# 4               0

# %%
count = data.groupby(['opponent', 'period','shot_type'])['shot_made_flag'].count()
count.head(30)
# Out:
# opponent           period  shot_type
# Atlanta Hawks      1       2PT Field Goal     7
#                            3PT Field Goal     3
#                    2       2PT Field Goal     6
#                            3PT Field Goal     1
#                    3       2PT Field Goal    10
#                            3PT Field Goal     1
#                    4       2PT Field Goal     9
#                            3PT Field Goal     4
# Boston Celtics     1       2PT Field Goal     7
#                            3PT Field Goal     7
#                    2       2PT Field Goal     2
#                            3PT Field Goal     3
#                    3       2PT Field Goal     7
#                            3PT Field Goal     5
#                    4       2PT Field Goal     3
#                            3PT Field Goal     2
# Brooklyn Nets      1       2PT Field Goal    11
#                            3PT Field Goal     2
#                    2       2PT Field Goal     7
#                            3PT Field Goal     2
#                    3       2PT Field Goal    10
#                            3PT Field Goal     1
#                    4       2PT Field Goal     8
#                            3PT Field Goal     2
# Charlotte Hornets  1       2PT Field Goal     8
#                            3PT Field Goal     1
#                    2       2PT Field Goal     6
#                            3PT Field Goal     4
#                    3       2PT Field Goal     9
#                            3PT Field Goal     1
# Name: shot_made_flag, dtype: int64

# %%
# gb = df.groupby('opponent')
gb = data.groupby(['opponent', 'period','shot_type'])['shot_made_flag'].sum();
gb.head(30)
# Out:
# opponent           period  shot_type
# Atlanta Hawks      1       2PT Field Goal    3
#                            3PT Field Goal    2
#                    2       2PT Field Goal    4
#                            3PT Field Goal    0
#                    3       2PT Field Goal    2
#                            3PT Field Goal    0
#                    4       2PT Field Goal    6
#                            3PT Field Goal    2
# Boston Celtics     1       2PT Field Goal    6
#                            3PT Field Goal    3
#                    2       2PT Field Goal    0
#                            3PT Field Goal    1
#                    3       2PT Field Goal    1
#                            3PT Field Goal    2
#                    4       2PT Field Goal    0
#                            3PT Field Goal    0
# Brooklyn Nets      1       2PT Field Goal    8
#                            3PT Field Goal    0
#                    2       2PT Field Goal    3
#                            3PT Field Goal    0
#                    3       2PT Field Goal    5
#                            3PT Field Goal    0
#                    4       2PT Field Goal    5
#                            3PT Field Goal    1
# Charlotte Hornets  1       2PT Field Goal    5
#                            3PT Field Goal    0
#                    2       2PT Field Goal    0
#                            3PT Field Goal    1
#                    3       2PT Field Goal    3
#                            3PT Field Goal    0
# Name: shot_made_flag, dtype: int64

# %%
mean = data.groupby(['opponent', 'period','shot_type'])['shot_made_flag'].mean();
mean.head(30)
# Out:
# opponent           period  shot_type
# Atlanta Hawks      1       2PT Field Goal    0.428571
#                            3PT Field Goal    0.666667
#                    2       2PT Field Goal    0.666667
#                            3PT Field Goal    0.000000
#                    3       2PT Field Goal    0.200000
#                            3PT Field Goal    0.000000
#                    4       2PT Field Goal    0.666667
#                            3PT Field Goal    0.500000
# Boston Celtics     1       2PT Field Goal    0.857143
#                            3PT Field Goal    0.428571
#                    2       2PT Field Goal    0.000000
#                            3PT Field Goal    0.333333
#                    3       2PT Field Goal    0.142857
#                            3PT Field Goal    0.400000
#                    4       2PT Field Goal    0.000000
#                            3PT Field Goal    0.000000
# Brooklyn Nets      1       2PT Field Goal    0.727273
#                            3PT Field Goal    0.000000
#                    2       2PT Field Goal    0.428571
#                            3PT Field Goal    0.000000
#                    3       2PT Field Goal    0.500000
#                            3PT Field Goal    0.000000
#                    4       2PT Field Goal    0.625000
#                            3PT Field Goal    0.500000
# Charlotte Hornets  1       2PT Field Goal    0.625000
#                            3PT Field Goal    0.000000
#                    2       2PT Field Goal    0.000000
#                            3PT Field Goal    0.250000
#                    3       2PT Field Goal    0.333333
#                            3PT Field Goal    0.000000
# Name: shot_made_flag, dtype: float64

# %%
data = mean.to_frame()
data.head()
# Out:
#                                      shot_made_flag
# opponent      period shot_type
# Atlanta Hawks 1      2PT Field Goal        0.428571
#                      3PT Field Goal        0.666667
#               2      2PT Field Goal        0.666667
#                      3PT Field Goal        0.000000
#               3      2PT Field Goal        0.200000

# %%
mean.head(20)
# Out:
# opponent        period  shot_type
# Atlanta Hawks   1       2PT Field Goal    0.428571
#                         3PT Field Goal    0.666667
#                 2       2PT Field Goal    0.666667
#                         3PT Field Goal    0.000000
#                 3       2PT Field Goal    0.200000
#                         3PT Field Goal    0.000000
#                 4       2PT Field Goal    0.666667
#                         3PT Field Goal    0.500000
# Boston Celtics  1       2PT Field Goal    0.857143
#                         3PT Field Goal    0.428571
#                 2       2PT Field Goal    0.000000
#                         3PT Field Goal    0.333333
#                 3       2PT Field Goal    0.142857
#                         3PT Field Goal    0.400000
#                 4       2PT Field Goal    0.000000
#                         3PT Field Goal    0.000000
# Brooklyn Nets   1       2PT Field Goal    0.727273
#                         3PT Field Goal    0.000000
#                 2       2PT Field Goal    0.428571
#                         3PT Field Goal    0.000000
# Name: shot_made_flag, dtype: float64

# %%
{"name": "NBA",
  "children": [
    {"name": "Minnesota Timberwolves",
     "children": [
      {"name": "Qtr 2",
        "children": [
          {"name": "2PT FG",
            "children": [
               {"name": "1"}
             ]
          },
          {"name": "3PT FG",
            "children": [
              {"name": "3"}
             ]
          }
         ]
      }
    ]},
     {"name": "Los Angeles",
     "children": [
      {"name": "Qtr 2",
        "children": [
          {"name": "2PT FG",
            "children": [
               {"name": "1"}
             ]
          },
          {"name": "3PT FG",
            "children": [
               {"name": "3"}
             ]
          }
         ]
      }
    ]
   }
 ]
}
# Out:
# {'children': [{'children': [{'children': [{'children': [{'name': '1'}],
#        'name': '2PT FG'},
#       {'children': [{'name': '3'}], 'name': '3PT FG'}],
#      'name': 'Qtr 2'}],
#    'name': 'Minnesota Timberwolves'},
#   {'children': [{'children': [{'children': [{'name': '1'}], 'name': '2PT FG'},
#       {'children': [{'name': '3'}], 'name': '3PT FG'}],
#      'name': 'Qtr 2'}],
#    'name': 'Los Angeles'}],
#  'name': 'NBA'}

# %%
for i, row in mean.iteritems():
    print(i[0], i[1], row)
# Out:
# (u'Atlanta Hawks', 1, 0.42857142857142855)
# (u'Atlanta Hawks', 1, 0.66666666666666663)
# (u'Atlanta Hawks', 2, 0.66666666666666663)
# (u'Atlanta Hawks', 2, 0.0)
# (u'Atlanta Hawks', 3, 0.20000000000000001)
# (u'Atlanta Hawks', 3, 0.0)
# (u'Atlanta Hawks', 4, 0.66666666666666663)
# (u'Atlanta Hawks', 4, 0.5)
# (u'Boston Celtics', 1, 0.8571428571428571)
# (u'Boston Celtics', 1, 0.42857142857142855)
# (u'Boston Celtics', 2, 0.0)
# (u'Boston Celtics', 2, 0.33333333333333331)
# (u'Boston Celtics', 3, 0.14285714285714285)
# (u'Boston Celtics', 3, 0.40000000000000002)
# (u'Boston Celtics', 4, 0.0)
# (u'Boston Celtics', 4, 0.0)
# (u'Brooklyn Nets', 1, 0.72727272727272729)
# (u'Brooklyn Nets', 1, 0.0)
# (u'Brooklyn Nets', 2, 0.42857142857142855)
# (u'Brooklyn Nets', 2, 0.0)
# (u'Brooklyn Nets', 3, 0.5)
# (u'Brooklyn Nets', 3, 0.0)
# (u'Brooklyn Nets', 4, 0.625)
# (u'Brooklyn Nets', 4, 0.5)
# (u'Charlotte Hornets', 1, 0.625)
# (u'Charlotte Hornets', 1, 0.0)
# (u'Charlotte Hornets', 2, 0.0)
# (u'Charlotte Hornets', 2, 0.25)
# (u'Charlotte Hornets', 3, 0.33333333333333331)
# (u'Charlotte Hornets', 3, 0.0)
# (u'Chicago Bulls', 1, 0.54545454545454541)
# (u'Chicago Bulls', 1, 0.0)
# (u'Chicago Bulls', 2, 0.5)
# (u'Chicago Bulls', 2, 0.0)
# (u'Chicago Bulls', 3, 0.25)
# (u'Chicago Bulls', 3, 0.5)
# (u'Chicago Bulls', 4, 0.42857142857142855)
# (u'Chicago Bulls', 4, 0.0)
# (u'Cleveland Cavaliers', 1, 0.55555555555555558)
# (u'Cleveland Cavaliers', 2, 0.5714285714285714)
# (u'Cleveland Cavaliers', 2, 1.0)
# (u'Cleveland Cavaliers', 3, 0.5)
# (u'Cleveland Cavaliers', 3, 0.0)
# (u'Cleveland Cavaliers', 4, 0.66666666666666663)
# (u'Cleveland Cavaliers', 4, 0.25)
# (u'Dallas Mavericks', 1, 0.42105263157894735)
# (u'Dallas Mavericks', 1, 0.25)
# (u'Dallas Mavericks', 2, 0.54545454545454541)
# (u'Dallas Mavericks', 2, 0.0)
# (u'Dallas Mavericks', 3, 0.7142857142857143)
# (u'Dallas Mavericks', 3, 0.25)
# (u'Dallas Mavericks', 4, 0.5)
# (u'Dallas Mavericks', 4, 0.66666666666666663)
# (u'Denver Nuggets', 1, 0.3125)
# (u'Denver Nuggets', 1, 0.25)
# (u'Denver Nuggets', 2, 0.5714285714285714)
# (u'Denver Nuggets', 2, 0.5)
# (u'Denver Nuggets', 3, 0.76470588235294112)
# (u'Denver Nuggets', 3, 0.375)
# (u'Denver Nuggets', 4, 0.80000000000000004)
# (u'Denver Nuggets', 4, 0.0)
# (u'Detroit Pistons', 1, 0.090909090909090912)
# (u'Detroit Pistons', 1, 0.0)
# (u'Detroit Pistons', 2, 0.80000000000000004)
# (u'Detroit Pistons', 2, 0.0)
# (u'Detroit Pistons', 3, 0.16666666666666666)
# (u'Detroit Pistons', 3, 0.0)
# (u'Detroit Pistons', 4, 0.0)
# (u'Detroit Pistons', 4, 0.59999999999999998)
# (u'Golden State Warriors', 1, 0.25)
# (u'Golden State Warriors', 1, 0.0)
# (u'Golden State Warriors', 2, 0.72727272727272729)
# (u'Golden State Warriors', 3, 0.16666666666666666)
# (u'Golden State Warriors', 3, 0.14285714285714285)
# (u'Golden State Warriors', 4, 0.5)
# (u'Golden State Warriors', 4, 0.0)
# (u'Golden State Warriors', 5, 0.25)
# (u'Golden State Warriors', 5, 0.0)
# (u'Houston Rockets', 1, 0.61538461538461542)
# (u'Houston Rockets', 1, 0.33333333333333331)
# (u'Houston Rockets', 2, 0.75)
# (u'Houston Rockets', 2, 0.33333333333333331)
# (u'Houston Rockets', 3, 0.0)
# (u'Houston Rockets', 3, 0.0)
# (u'Houston Rockets', 4, 0.70588235294117652)
# (u'Houston Rockets', 4, 0.25)
# (u'Indiana Pacers', 1, 0.42857142857142855)
# (u'Indiana Pacers', 1, 0.5)
# (u'Indiana Pacers', 2, 1.0)
# (u'Indiana Pacers', 2, 0.33333333333333331)
# (u'Indiana Pacers', 3, 0.5714285714285714)
# (u'Indiana Pacers', 3, 0.5)
# (u'Indiana Pacers', 4, 0.20000000000000001)
# (u'Indiana Pacers', 4, 0.0)
# (u'Los Angeles Clippers', 1, 0.5)
# (u'Los Angeles Clippers', 1, 0.5)
# (u'Los Angeles Clippers', 2, 0.6428571428571429)
# (u'Los Angeles Clippers', 2, 0.0)
# (u'Los Angeles Clippers', 3, 0.6428571428571429)
# (u'Los Angeles Clippers', 3, 0.29999999999999999)
# (u'Los Angeles Clippers', 4, 0.27777777777777779)
# (u'Los Angeles Clippers', 4, 0.5)
# (u'Los Angeles Lakers', 1, 0.63157894736842102)
# (u'Los Angeles Lakers', 1, 0.0)
# (u'Los Angeles Lakers', 2, 0.47058823529411764)
# (u'Los Angeles Lakers', 2, 0.0)
# (u'Los Angeles Lakers', 3, 0.4375)
# (u'Los Angeles Lakers', 3, 0.0)
# (u'Los Angeles Lakers', 4, 0.75)
# (u'Los Angeles Lakers', 4, 0.5)
# (u'Memphis Grizzlies', 1, 0.66666666666666663)
# (u'Memphis Grizzlies', 1, 0.0)
# (u'Memphis Grizzlies', 2, 0.59999999999999998)
# (u'Memphis Grizzlies', 2, 1.0)
# (u'Memphis Grizzlies', 3, 0.55555555555555558)
# (u'Memphis Grizzlies', 3, 0.75)
# (u'Memphis Grizzlies', 4, 0.66666666666666663)
# (u'Memphis Grizzlies', 4, 0.5)
# (u'Miami Heat', 1, 0.54545454545454541)
# (u'Miami Heat', 1, 0.0)
# (u'Miami Heat', 2, 0.42857142857142855)
# (u'Miami Heat', 2, 0.0)
# (u'Miami Heat', 3, 0.42857142857142855)
# (u'Miami Heat', 3, 1.0)
# (u'Miami Heat', 4, 0.0)
# (u'Miami Heat', 4, 0.0)
# (u'Milwaukee Bucks', 1, 0.42857142857142855)
# (u'Milwaukee Bucks', 2, 0.75)
# (u'Milwaukee Bucks', 3, 0.33333333333333331)
# (u'Milwaukee Bucks', 3, 0.20000000000000001)
# (u'Milwaukee Bucks', 4, 0.5714285714285714)
# (u'Minnesota Timberwolves', 1, 0.46153846153846156)
# (u'Minnesota Timberwolves', 1, 1.0)
# (u'Minnesota Timberwolves', 2, 0.5)
# (u'Minnesota Timberwolves', 2, 0.5714285714285714)
# (u'Minnesota Timberwolves', 3, 0.75)
# (u'Minnesota Timberwolves', 3, 0.5)
# (u'Minnesota Timberwolves', 4, 0.14285714285714285)
# (u'Minnesota Timberwolves', 4, 0.33333333333333331)
# (u'New Orleans Pelicans', 1, 0.625)
# (u'New Orleans Pelicans', 1, 0.33333333333333331)
# (u'New Orleans Pelicans', 2, 0.81818181818181823)
# (u'New Orleans Pelicans', 2, 0.0)
# (u'New Orleans Pelicans', 3, 0.58333333333333337)
# (u'New Orleans Pelicans', 3, 0.33333333333333331)
# (u'New Orleans Pelicans', 4, 0.5)
# (u'New Orleans Pelicans', 4, 0.66666666666666663)
# (u'New York Knicks', 1, 0.40000000000000002)
# (u'New York Knicks', 1, 0.0)
# (u'New York Knicks', 2, 0.59999999999999998)
# (u'New York Knicks', 2, 1.0)
# (u'New York Knicks', 3, 0.625)
# (u'New York Knicks', 3, 0.0)
# (u'New York Knicks', 4, 0.55555555555555558)
# (u'New York Knicks', 4, 0.16666666666666666)
# (u'New York Knicks', 5, 0.5)
# (u'Orlando Magic', 1, 0.58333333333333337)
# (u'Orlando Magic', 2, 0.2857142857142857)
# (u'Orlando Magic', 2, 0.0)
# (u'Orlando Magic', 3, 0.41666666666666669)
# (u'Orlando Magic', 4, 0.75)
# (u'Orlando Magic', 4, 1.0)
# (u'Orlando Magic', 5, 0.80000000000000004)
# (u'Orlando Magic', 5, 0.0)
# (u'Orlando Magic', 6, 0.5)
# (u'Orlando Magic', 6, 0.0)
# (u'Philadelphia 76ers', 1, 0.40000000000000002)
# (u'Philadelphia 76ers', 1, 0.0)
# (u'Philadelphia 76ers', 2, 0.42857142857142855)
# (u'Philadelphia 76ers', 2, 0.0)
# (u'Philadelphia 76ers', 3, 0.41666666666666669)
# (u'Philadelphia 76ers', 3, 1.0)
# (u'Philadelphia 76ers', 4, 0.0)
# (u'Philadelphia 76ers', 4, 0.75)
# (u'Phoenix Suns', 1, 0.73333333333333328)
# (u'Phoenix Suns', 1, 0.66666666666666663)
# (u'Phoenix Suns', 2, 0.40000000000000002)
# (u'Phoenix Suns', 2, 0.5)
# (u'Phoenix Suns', 3, 0.42857142857142855)
# (u'Phoenix Suns', 3, 0.0)
# (u'Phoenix Suns', 4, 0.625)
# (u'Phoenix Suns', 4, 0.0)
# (u'Portland Trail Blazers', 1, 0.53846153846153844)
# (u'Portland Trail Blazers', 1, 0.0)
# (u'Portland Trail Blazers', 2, 0.25)
# (u'Portland Trail Blazers', 2, 0.0)
# (u'Portland Trail Blazers', 3, 0.42857142857142855)
# (u'Portland Trail Blazers', 3, 1.0)
# (u'Portland Trail Blazers', 4, 0.66666666666666663)
# (u'Portland Trail Blazers', 4, 0.5)
# (u'Sacramento Kings', 1, 0.72727272727272729)
# (u'Sacramento Kings', 1, 0.25)
# (u'Sacramento Kings', 2, 0.5714285714285714)
# (u'Sacramento Kings', 2, 0.59999999999999998)
# (u'Sacramento Kings', 3, 0.38461538461538464)
# (u'Sacramento Kings', 3, 0.0)
# (u'Sacramento Kings', 4, 0.375)
# (u'Sacramento Kings', 4, 0.33333333333333331)
# (u'San Antonio Spurs', 1, 0.5)
# (u'San Antonio Spurs', 1, 0.40000000000000002)
# (u'San Antonio Spurs', 2, 0.69230769230769229)
# (u'San Antonio Spurs', 2, 0.5)
# (u'San Antonio Spurs', 3, 0.59999999999999998)
# (u'San Antonio Spurs', 3, 0.0)
# (u'San Antonio Spurs', 4, 0.125)
# (u'San Antonio Spurs', 4, 0.5)
# (u'Toronto Raptors', 1, 0.40000000000000002)
# (u'Toronto Raptors', 1, 0.25)
# (u'Toronto Raptors', 2, 0.66666666666666663)
# (u'Toronto Raptors', 2, 0.0)
# (u'Toronto Raptors', 3, 0.875)
# (u'Toronto Raptors', 3, 1.0)
# (u'Toronto Raptors', 4, 0.16666666666666666)
# (u'Toronto Raptors', 4, 0.33333333333333331)
# (u'Utah Jazz', 1, 0.63636363636363635)
# (u'Utah Jazz', 1, 0.20000000000000001)
# (u'Utah Jazz', 2, 0.29999999999999999)
# (u'Utah Jazz', 2, 0.5)
# (u'Utah Jazz', 3, 0.80000000000000004)
# (u'Utah Jazz', 4, 0.0)
# (u'Utah Jazz', 4, 0.0)
# (u'Utah Jazz', 5, 0.40000000000000002)
# (u'Utah Jazz', 5, 0.0)
# (u'Washington Wizards', 1, 0.625)
# (u'Washington Wizards', 2, 0.33333333333333331)
# (u'Washington Wizards', 2, 0.25)
# (u'Washington Wizards', 3, 0.625)
# (u'Washington Wizards', 3, 1.0)
# (u'Washington Wizards', 4, 0.0)
# (u'Washington Wizards', 4, 0.0)

# %%
# print row['opponent'], row['period'], row['shot_type'], row['shot_made_flag']

team = ""
qtr = 0
count = 0

print "{\"name\": \"Westbrook\","
print "\t\"children\": ["

#for index, row in data.iterrows():
for i, row in mean.iteritems():
    if (i[0] != team):
        if (count != 0):
            print "\t\t\t\t\t]"
            print "\t\t\t\t}" 
            print "\t\t\t]"
            print "\t\t},"
        print "\t\t{\"name\": \"" + i[0] + "\","
        print "\t\t\t\"children\": ["
        print "\t\t\t\t{\"name\": \"Qtr " + str(i[1]) + "\","
        print "\t\t\t\t\t\"children\": ["
        print "\t\t\t\t\t\t{\"name\": \"" + i[2].split()[0] + " FG Percentage: " + str(round(row, 2)) + "\"},"
        #print "]"
        #print "}]"
        #print "},"
        
        team = i[0]
        qtr = i[1]
        count += 1
    
    elif (i[1] != qtr):
        if(i[1] != 1):
            print "\t\t\t\t\t]"
            print "\t\t\t\t},"
            print "\t\t\t\t{\"name\": \"Qtr " + str(i[1]) + "\","
            print "\t\t\t\t\t\"children\": ["
            print "\t\t\t\t\t\t{\"name\": \"" + i[2].split()[0] + " FG Percentage: " + str(round(row, 2)) + "\"},"
        
        elif(index[1] == 1):
            print "\t\t\t\t{\"name\": \"Qtr " + str(i[1]) + "\","
            print "\t\t\t\t\t\"children\": ["
            print "\t\t\t\t\t\t{\"name\": \"" + i[2].split()[0] + " FG Percentage: " + str(round(row, 2)) + "\"},"
            print "\t\t\t\t\t]"
            print "\t\t\t\t},"
            
        qtr = i[1]
          
    else:
        print "\t\t\t\t\t\t{\"name\": \"" + i[2].split()[0] + " FG Percentage: " + str(round(row, 2)) + "\"},"

print "\t\t\t]"
print "\t\t}"        
print "\t]"
print "}"
# Out:
# {"name": "Westbrook",
# 	"children": [
# 		{"name": "Atlanta Hawks",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.67"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.2"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Boston Celtics",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.86"},
# 						{"name": "3PT FG Percentage: 0.43"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.14"},
# 						{"name": "3PT FG Percentage: 0.4"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Brooklyn Nets",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.73"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Charlotte Hornets",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.33"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Chicago Bulls",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.55"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.25"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Cleveland Cavaliers",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.56"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.57"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Dallas Mavericks",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.42"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.55"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.71"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.67"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Denver Nuggets",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.31"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.57"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.76"},
# 						{"name": "3PT FG Percentage: 0.38"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.8"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Detroit Pistons",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.09"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.8"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.17"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.6"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Golden State Warriors",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.25"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.73"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.17"},
# 						{"name": "3PT FG Percentage: 0.14"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 5",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.25"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Houston Rockets",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.62"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.75"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.71"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Indiana Pacers",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 1.0"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.57"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.2"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Los Angeles Clippers",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.64"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.64"},
# 						{"name": "3PT FG Percentage: 0.3"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.28"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Los Angeles Lakers",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.47"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.44"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.75"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Memphis Grizzlies",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.6"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.56"},
# 						{"name": "3PT FG Percentage: 0.75"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Miami Heat",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.55"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Milwaukee Bucks",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.75"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.33"},
# 						{"name": "3PT FG Percentage: 0.2"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.57"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Minnesota Timberwolves",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.46"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.57"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.75"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.14"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "New Orleans Pelicans",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.82"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.58"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.67"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "New York Knicks",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.4"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.6"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.56"},
# 						{"name": "3PT FG Percentage: 0.17"},
# 					]
# 				},
# 				{"name": "Qtr 5",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Orlando Magic",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.58"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.29"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.42"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.75"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 5",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.8"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 6",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Philadelphia 76ers",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.4"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.42"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.75"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Phoenix Suns",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.73"},
# 						{"name": "3PT FG Percentage: 0.67"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.4"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Portland Trail Blazers",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.54"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.25"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.43"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Sacramento Kings",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.73"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.57"},
# 						{"name": "3PT FG Percentage: 0.6"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.38"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.38"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "San Antonio Spurs",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.5"},
# 						{"name": "3PT FG Percentage: 0.4"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.69"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.6"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.13"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Toronto Raptors",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.4"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.67"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.88"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.17"},
# 						{"name": "3PT FG Percentage: 0.33"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Utah Jazz",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.64"},
# 						{"name": "3PT FG Percentage: 0.2"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.3"},
# 						{"name": "3PT FG Percentage: 0.5"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.8"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				},
# 				{"name": "Qtr 5",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.4"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 					]
# 				}
# 			]
# 		},
# 		{"name": "Washington Wizards",
# 			"children": [
# 				{"name": "Qtr 1",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 					]
# 				},
# 				{"name": "Qtr 2",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.33"},
# 						{"name": "3PT FG Percentage: 0.25"},
# 					]
# 				},
# 				{"name": "Qtr 3",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.63"},
# 						{"name": "3PT FG Percentage: 1.0"},
# 					]
# 				},
# 				{"name": "Qtr 4",
# 					"children": [
# 						{"name": "2PT FG Percentage: 0.0"},
# 						{"name": "3PT FG Percentage: 0.0"},
# 			]
# 		}
# 	]
# }

# %%
# print row['opponent'], row['period'], row['shot_type'], row['shot_made_flag']

team = ""
count = 0

print "{\"name\": \"Westbrook\","
print "\"children\": ["

for index, row in data.iterrows():
    if (index[0] != team):
        print "}]"
        print "{\"name\": \"" + index[0] + "\","
        print "\"children\": ["
        print "{\"name\": \"Qtr " + str(index[1]) + "\","
        print "\"children\": ["
        print "{\"name\": \"" + index[2].split()[0] + " FG\"}"
        print "]"
        #print "}]"
        print "},"
        
        team = index[0]
    
    else:
        print "{\"name\": \"Qtr " + str(index[1]) + "\","
        print "\"children\": ["
        print "{\"name\": \"" + index[2].split()[0] + " FG\"}"
        print "]"
        print "},"
        
print "]"
print "}"

# %%
# print row['opponent'], row['period'], row['shot_type'], row['shot_made_flag']

print "{\"name\": \"Westbrook\","
print "\"children\": ["

for index, row in data.iterrows():
    if (index[0] == "Atlanta Hawks"):
        print "{\"name\": \"" + index[0] + "\","
        print "\"children\": ["
        print "{\"name\": \"Qtr " + str(index[1]) + "\","
        print "\"children\": ["
        print "{\"name\": \"" + index[2].split()[0] + " FG\"}"
        print "]"
        print "}]"
        print "},"

print "]"
print "}"
